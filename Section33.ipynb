# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('real_estate_price_size.csv')

# %%
data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
y = data['price']
x1 = data['size']

# %%
plt.scatter(x1,y)
plt.xlabel('Size',fontsize = 20)
plt.ylabel('Price', fontsize = 20)
plt.show()

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Fri, 12 Aug 2022   Prob (F-statistic):           8.13e-31
# Time:                        15:23:57   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.019e+05   1.19e+04      8.550      0.000    7.83e+04    1.26e+05
# ...

# %%
plt.scatter(x1,y)
yhat = 223.1787*x1 + 101900 
plt.plot(x1,yhat, lw = 2, c = 'Red', label = 'Regression Line')
plt.xlabel('Size', fontsize = 20)
plt.ylabel('Price', fontsize = 20)
plt.show()

# %%
data = pd.read_csv('real_estate_price_size_year.csv')

# %%
data
# Out:
#          price     size  year
# 0   234314.144   643.09  2015
# 1   228581.528   656.22  2009
# 2   281626.336   487.29  2018
# 3   401255.608  1504.75  2015
# 4   458674.256  1275.46  2009
# ..         ...      ...   ...
# 95  252460.400   549.80  2009
# 96  310522.592  1037.44  2009
# 97  383635.568  1504.75  2006
# 98  225145.248   648.29  2015
# 99  274922.856   705.29  2006
#
# [100 rows x 3 columns]

# %%
y = data['price']
x1 = data[['size','year']]

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     168.5
# Date:                Sat, 13 Aug 2022   Prob (F-statistic):           2.77e-32
# Time:                        16:25:39   Log-Likelihood:                -1191.7
# No. Observations:                 100   AIC:                             2389.
# Df Residuals:                      97   BIC:                             2397.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.772e+06   1.58e+06     -3.647      0.000   -8.91e+06   -2.63e+06
# ...

# %%
plt.scatter(x1,y)
yhat = 227.7009*x1 -5772000 
plt.plot(x1,yhat, lw = 2, c = 'Red', label = 'Regression Line')
plt.xlabel('Size', fontsize = 20)
plt.ylabel('Price', fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 plt.scatter(x1,y)
#       2 yhat = 227.7009*x1 -5772000
#       3 plt.plot(x1,yhat, lw = 2, c = 'Red', label = 'Regression Line')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2802 @_copy_docstring_and_deprecators(Axes.scatter)
#    2803 def scatter(
#    2804         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %%
raw_data = pd.read_csv('real_estate_price_size_year_view.csv')

# %%
raw_data
# Out:
#          price     size  year         view
# 0   234314.144   643.09  2015  No sea view
# 1   228581.528   656.22  2009  No sea view
# 2   281626.336   487.29  2018     Sea view
# 3   401255.608  1504.75  2015  No sea view
# 4   458674.256  1275.46  2009     Sea view
# ..         ...      ...   ...          ...
# 95  252460.400   549.80  2009     Sea view
# 96  310522.592  1037.44  2009  No sea view
# 97  383635.568  1504.75  2006  No sea view
# 98  225145.248   648.29  2015  No sea view
# 99  274922.856   705.29  2006     Sea view
#
# [100 rows x 4 columns]

# %%
data = raw_data.copy()

# %%
data['view'] = data['view'].map({'Sea view':1,'No sea view':0})

# %% [raw]
# data

# %%
data
# Out:
#          price     size  year  view
# 0   234314.144   643.09  2015     0
# 1   228581.528   656.22  2009     0
# 2   281626.336   487.29  2018     1
# 3   401255.608  1504.75  2015     0
# 4   458674.256  1275.46  2009     1
# ..         ...      ...   ...   ...
# 95  252460.400   549.80  2009     1
# 96  310522.592  1037.44  2009     0
# 97  383635.568  1504.75  2006     0
# 98  225145.248   648.29  2015     0
# 99  274922.856   705.29  2006     1
#
# [100 rows x 4 columns]

# %%
data.describe()
# Out:
#                price         size         year        view
# count     100.000000   100.000000   100.000000  100.000000
# mean   292289.470160   853.024200  2012.600000    0.490000
# std     77051.727525   297.941951     4.729021    0.502418
# min    154282.128000   479.750000  2006.000000    0.000000
# 25%    234280.148000   643.330000  2009.000000    0.000000
# 50%    280590.716000   696.405000  2015.000000    0.000000
# 75%    335723.696000  1029.322500  2018.000000    1.000000
# max    500681.128000  1842.510000  2018.000000    1.000000

# %%
y = data['price']
x1 = data[['size','year','view']]
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     335.2
# Date:                Mon, 15 Aug 2022   Prob (F-statistic):           1.02e-50
# Time:                        20:36:15   Log-Likelihood:                -1144.6
# No. Observations:                 100   AIC:                             2297.
# Df Residuals:                      96   BIC:                             2308.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.398e+06   9.94e+05     -5.431      0.000   -7.37e+06   -3.43e+06
# ...

# %%
plt.scatter(data['size'],y)
yhat_no_sea_view = -5398000 + 223.0316*data['size'] + 2718.9489*data['year'] 
yhat_sea_view = -5341270 + 223.0316*data['size'] + 2718.9489*data['year'] 
fig = plt.plot(data['size'], yhat_no_sea_view, lw = 2, c = '#006837')
fig = plt.plot(data['size'], yhat_sea_view, lw = 2, c = '#a50026')
plt.xlabel('Size',fontsize = 20)
plt.ylabel('Price',fontsize = 20)
plt.show()

# %%
data
# Out:
#          price     size  year  view
# 0   234314.144   643.09  2015     0
# 1   228581.528   656.22  2009     0
# 2   281626.336   487.29  2018     1
# 3   401255.608  1504.75  2015     0
# 4   458674.256  1275.46  2009     1
# ..         ...      ...   ...   ...
# 95  252460.400   549.80  2009     1
# 96  310522.592  1037.44  2009     0
# 97  383635.568  1504.75  2006     0
# 98  225145.248   648.29  2015     0
# 99  274922.856   705.29  2006     1
#
# [100 rows x 4 columns]

# %%
plt.scatter(data['size'],y)
yhat_no_sea_view = -5398000 + 223.0316*data['size'] + 2718.9489*data['year'] 
yhat_sea_view = -5341270 + 223.0316*data['size'] + 2718.9489*data['year'] 
yhat_mixed = -5398000 + 223.0316*data['size'] + 2718.9489*data['year'] + 56730*data['view']
fig = plt.plot(data['size'], yhat_no_sea_view, lw = 2, c = '#006837')
fig = plt.plot(data['size'], yhat_sea_view, lw = 2, c = '#a50026')
fig = plt.plot(data['size'], yhat_mixed, lw = 2, c = '#000000')
plt.xlabel('Size',fontsize = 20)
plt.ylabel('Price',fontsize = 20)
plt.show()

# %%
plt.scatter(data['size'],y, c = data['view'], cmap = 'RdYlGn_r')
yhat_no_sea_view = -5398000 + 223.0316*data['size'] + 2718.9489*data['year'] 
yhat_sea_view = -5341270 + 223.0316*data['size'] + 2718.9489*data['year'] 
yhat_mixed = -5398000 + 223.0316*data['size'] + 2718.9489*data['year'] + 56730*data['view']
fig = plt.plot(data['size'], yhat_no_sea_view, lw = 2, c = '#006837')
fig = plt.plot(data['size'], yhat_sea_view, lw = 2, c = '#a50026')
fig = plt.plot(data['size'], yhat_mixed, lw = 2, c = '#000000')
plt.xlabel('Size',fontsize = 20)
plt.ylabel('Price',fontsize = 20)
plt.show()

# %%
##Trying to create new data frame to predict values

# %%
data
# Out:
#          price     size  year  view
# 0   234314.144   643.09  2015     0
# 1   228581.528   656.22  2009     0
# 2   281626.336   487.29  2018     1
# 3   401255.608  1504.75  2015     0
# 4   458674.256  1275.46  2009     1
# ..         ...      ...   ...   ...
# 95  252460.400   549.80  2009     1
# 96  310522.592  1037.44  2009     0
# 97  383635.568  1504.75  2006     0
# 98  225145.248   648.29  2015     0
# 99  274922.856   705.29  2006     1
#
# [100 rows x 4 columns]

# %%
x
# Out:
#     const     size  year  view
# 0     1.0   643.09  2015     0
# 1     1.0   656.22  2009     0
# 2     1.0   487.29  2018     1
# 3     1.0  1504.75  2015     0
# 4     1.0  1275.46  2009     1
# ..    ...      ...   ...   ...
# 95    1.0   549.80  2009     1
# 96    1.0  1037.44  2009     0
# 97    1.0  1504.75  2006     0
# 98    1.0   648.29  2015     0
# 99    1.0   705.29  2006     1
#
# [100 rows x 4 columns]

# %%
new_data = pd.DataFrame({'const':1,'size':[1200,1200],'year':[2022,2022],'view':[0,1]})

# %%
new_data
# Out:
#    const  size  year  view
# 0      1  1200  2022     0
# 1      1  1200  2022     1

# %%
new_data.rename(index = {0:'Anshul',1:'Anurag'})
# Out:
#         const  size  year  view
# Anshul      1  1200  2022     0
# Anurag      1  1200  2022     1

# %%
predictions = results.predict(new_data)
predications_df = pd.DataFrame({'Predictions':predictions})
joined = new_data.join(predications_df)
joined.rename(index = {0:'Anshul',1:'Anurag'})
# Out:
#         const  size  year  view    Predictions
# Anshul      1  1200  2022     0  367438.414593
# Anurag      1  1200  2022     1  424164.434392
